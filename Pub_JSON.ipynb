# %% [markdown]
# <a href="https://colab.research.google.com/github/eddyooi/ECE3186/blob/main/Pub_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install paho-mqtt

# %%
import paho.mqtt.client as paho
from json import dumps
from time import sleep
broker="test.mosquitto.org"
port=1883
i = 1
def on_publish(client,userdata,result):             # callback function for data publish
	print(f"Data published: {data}")
client1= paho.Client("pub1")                        # create client object
client1.on_publish = on_publish                     # assign function to callback
client1.connect(broker,port)                        # establish connection
while True:
    data = dumps(dict(temp=i*2, humi=i*5))          # encode Python dictionary as json
    ret= client1.publish("mypi/sensor", data)       # publish data to topic “mypi/sensor”
    i += 1
    sleep(5)
# Out:
# Data published: {"temp": 2, "humi": 5}
# Data published: {"temp": 4, "humi": 10}
# Data published: {"temp": 6, "humi": 15}
# Data published: {"temp": 8, "humi": 20}
# Data published: {"temp": 10, "humi": 25}
# Data published: {"temp": 12, "humi": 30}
# Data published: {"temp": 14, "humi": 35}
# Data published: {"temp": 16, "humi": 40}
# Data published: {"temp": 18, "humi": 45}
# Data published: {"temp": 20, "humi": 50}
# Data published: {"temp": 22, "humi": 55}
# Data published: {"temp": 24, "humi": 60}
# Data published: {"temp": 26, "humi": 65}
# Data published: {"temp": 28, "humi": 70}
# Data published: {"temp": 30, "humi": 75}
# Data published: {"temp": 32, "humi": 80}
# Data published: {"temp": 34, "humi": 85}
# Data published: {"temp": 36, "humi": 90}
# Data published: {"temp": 38, "humi": 95}
# Data published: {"temp": 40, "humi": 100}
# Data published: {"temp": 42, "humi": 105}
# Data published: {"temp": 44, "humi": 110}
# Data published: {"temp": 46, "humi": 115}
# ...
